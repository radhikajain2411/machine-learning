# %% [markdown]
# <a href="https://colab.research.google.com/github/radhikajain2411/machine-learning/blob/main/Automobile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h2>Mtcars, the automobile company in the United States, has planned to rework on optimizing the horsepower of its cars as most of the customers’ feedback was centred around horsepower.</h2>
#
# <h4>
# PartA :    The company is coming up with a new model based on the feedback given by its customers. It has to explore the current dataset to derive further insights from it.</h4>
# <h4>
# PartB : However, while developing an ML model with respect to horsepower, the efficiency of the model was compromised. Irregularity might be one of the causes.</h4>

# %% [markdown]
# <center><b>Part A</b></center>
# <h4>Import the dataset, explore for dimensionality, and type and average value of the horsepower across all the cars. Also, identify a few of mostly correlated features, which would help
# in modification.</h4>

# %%
#Importing necessary Library
import pandas as pd

# %%
#Importing mtcars dataset
df = pd.read_csv("mtcars.csv")

# %%
df
# Out:
#                   model   mpg  cyl   disp   hp  ...   qsec  vs  am  gear  carb
# 0             Mazda RX4  21.0    6  160.0  110  ...  16.46   0   1     4     4
# 1         Mazda RX4 Wag  21.0    6  160.0  110  ...  17.02   0   1     4     4
# 2            Datsun 710  22.8    4  108.0   93  ...  18.61   1   1     4     1
# 3        Hornet 4 Drive  21.4    6  258.0  110  ...  19.44   1   0     3     1
# 4     Hornet Sportabout  18.7    8  360.0  175  ...  17.02   0   0     3     2
# 5               Valiant  18.1    6  225.0  105  ...  20.22   1   0     3     1
# 6            Duster 360  14.3    8  360.0  245  ...  15.84   0   0     3     4
# 7             Merc 240D  24.4    4  146.7   62  ...  20.00   1   0     4     2
# 8              Merc 230  22.8    4  140.8   95  ...  22.90   1   0     4     2
# 9              Merc 280  19.2    6  167.6  123  ...  18.30   1   0     4     4
# 10            Merc 280C  17.8    6  167.6  123  ...  18.90   1   0     4     4
# ...

# %%
#check Dimensionality
df.shape
# Out:
# (32, 12)

# %%
#type of Dataset
type(df)
type(df['hp'])
# Out:
# pandas.core.series.Series

# %%
#average of Datatset
df['hp'].mean()
# Out:
# 146.6875

# %%
#mostly correlated features
df.corr()
# Out:
#            mpg       cyl      disp  ...        am      gear      carb
# mpg   1.000000 -0.852162 -0.847551  ...  0.599832  0.480285 -0.550925
# cyl  -0.852162  1.000000  0.902033  ... -0.522607 -0.492687  0.526988
# disp -0.847551  0.902033  1.000000  ... -0.591227 -0.555569  0.394977
# hp   -0.776168  0.832447  0.790949  ... -0.243204 -0.125704  0.749812
# drat  0.681172 -0.699938 -0.710214  ...  0.712711  0.699610 -0.090790
# wt   -0.867659  0.782496  0.887980  ... -0.692495 -0.583287  0.427606
# qsec  0.418684 -0.591242 -0.433698  ... -0.229861 -0.212682 -0.656249
# vs    0.664039 -0.810812 -0.710416  ...  0.168345  0.206023 -0.569607
# am    0.599832 -0.522607 -0.591227  ...  1.000000  0.794059  0.057534
# gear  0.480285 -0.492687 -0.555569  ...  0.794059  1.000000  0.274073
# carb -0.550925  0.526988  0.394977  ...  0.057534  0.274073  1.000000
#
# [11 rows x 11 columns]

# %% [markdown]
# <center><b>Part B</b></center>
# <h4>Check for missing values and outliers within the horsepower column and remove them.</h4>

# %%
#check for the mising values
df.isnull().any()
# Out:
# model    False
# mpg      False
# cyl      False
# disp     False
# hp       False
# drat     False
# wt       False
# qsec     False
# vs       False
# am       False
# gear     False
# carb     False
# dtype: bool

# %%
#Using seaborn library
import seaborn as sns

# %%
#Creating a boxplot to identify outlier present in horsepower column
sns.boxplot(df['hp'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Filtering out the Outliers
filter = df['hp'].values>250
df_outlier_rem = df[filter]
df_outlier_rem
# Out:
#              model   mpg  cyl   disp   hp  drat    wt  qsec  vs  am  gear  carb
# 28  Ford Pantera L  15.8    8  351.0  264  4.22  3.17  14.5   0   1     5     4
# 30   Maserati Bora  15.0    8  301.0  335  3.54  3.57  14.6   0   1     5     8

# %%
#Droping the outlier from the Dataset
df.drop(28,inplace=True)
df.drop(30,inplace=True)

# %%
#Now there is no outlier present in horsepower column
sns.boxplot(df['hp'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Thank you
